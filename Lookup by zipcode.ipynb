# %%
import pandas as pd

load_data = lambda x, **kwargs: pd.read_csv(x, sep='\t', **kwargs)

zipcode_table = load_data('UCMR3_ZipCodes.txt')

zipcode_to_PWSID = lambda x: list(zipcode_table[zipcode_table['ZIPCODE'] == x]['PWSID'])[0]

results = load_data('UCMR3_All.txt', encoding='latin1')

#drt_table = load_data('UCMR3_DRT.txt')

# %%
zipcode_table
# Out:
#            PWSID ZIPCODE
# 0      010106001   06339
# 1      010109005   06382
# 2      055293201   48858
# 3      055294506   55372
# 4      055295003   54416
# 5      063506008   88340
# 6      063506114   87004
# 7      083890023   57401
# 8      090400109   85256
# 9      090400693   85941
# 10     090407149   85256
# 11     090600142     NaN
# 12     090605013   92953
# 13     090605107   95606
# 14     090605153   92059
# 15     AK2110342   99801
# 16     AK2210906   99503
# 17     AK2211423   99506
# 18     AK2224646   99654
# 19     AK2310730   99701
# 20     AK2310730   99706
# 21     AK2310730   99707
# 22     AK2310730   99708
# 23     AK2310730   99709
# 24     AK2310900   99701
# 25     AK2310900   99706
# 26     AK2310900   99707
# 27     AK2310900   99708
# 28     AK2310900   99709
# 29     AK2310918   99703
# ...          ...     ...
# 11661  KY0900031   40004
# 11662  KY0900031   40012
# 11663  KY0930481   40031
# 11664  KY0960499   41040
# 11665  KY0960499   41097
# ...

# %%
#list(zipcode_table[zipcode_table['ZIPCODE'] == '93728']['PWSID'])[0]
our_pwsid = zipcode_to_PWSID('93728')
our_pwsid
# Out:
# 'CA1010007'

# %%
f = results['PWSID'] == our_pwsid
u = results['AnalyticalResultsSign'] == '='
our_rows = results[f&u]
our_rows
# Out:
#             PWSID         PWSName Size  FacilityID FacilityName  \
# 876887  CA1010007  City of Fresno    L       91858   Well 148/1
# 876904  CA1010007  City of Fresno    L       91858   Well 148/1
# 876906  CA1010007  City of Fresno    L       91858   Well 148/1
# 876910  CA1010007  City of Fresno    L       91858   Well 148/1
# 876912  CA1010007  City of Fresno    L       91858   Well 148/1
# 876916  CA1010007  City of Fresno    L       91858   Well 148/1
# 876920  CA1010007  City of Fresno    L       91857   Well 148-2
# 876934  CA1010007  City of Fresno    L       91857   Well 148-2
# 876935  CA1010007  City of Fresno    L       91857   Well 148-2
# 876937  CA1010007  City of Fresno    L       91857   Well 148-2
# 876939  CA1010007  City of Fresno    L       91857   Well 148-2
# 876941  CA1010007  City of Fresno    L       91857   Well 148-2
# 876947  CA1010007  City of Fresno    L       91857   Well 148-2
# 876957  CA1010007  City of Fresno    L       91858   Well 148/1
# ...

# %%
ref_levels = pd.read_csv('epa_regulation_levels.csv', index_col='Contaminant')

# %%
ref_levels.ix['cobalt', 'Reference Concentration']
# Out:
# 70.0

# %%
doselect = lambda x: ref_levels.ix[our_rows.ix[x, 'Contaminant'], 'Reference Concentration'] <= our_rows.ix[x, 'AnalyticalResultValue'] 
exceeded_levels = our_rows.select(doselect)

# %%
exceeded_levels
# Out:
#             PWSID         PWSName Size  FacilityID FacilityName  \
# 877024  CA1010007  City of Fresno    L       91854     Well 197
# 877036  CA1010007  City of Fresno    L       91854     Well 197
# 877040  CA1010007  City of Fresno    L       91854     Well 197
# 877050  CA1010007  City of Fresno    L       91854     Well 197
# 877080  CA1010007  City of Fresno    L       91856   Well 165-2
# 877106  CA1010007  City of Fresno    L       91856   Well 165-2
# 877116  CA1010007  City of Fresno    L       91856   Well 165-2
# 877124  CA1010007  City of Fresno    L       91856   Well 165-2
# 877127  CA1010007  City of Fresno    L       91856   Well 165-2
# 877141  CA1010007  City of Fresno    L       91863   Well 164-1
# 877153  CA1010007  City of Fresno    L       91863   Well 164-1
# 877183  CA1010007  City of Fresno    L       91863   Well 164-1
# 877200  CA1010007  City of Fresno    L       91864   Well 153-1
# 877210  CA1010007  City of Fresno    L       91864   Well 153-1
# ...
